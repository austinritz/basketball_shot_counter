# %%
from ultralytics import YOLO

model = YOLO('./runs/detect/train4/weights/best.pt')  # initialize model
###results = model.train(data='/home/austritz/datasets/basketball/data.yaml', epochs=20, imgsz=640)

# %%
results = model('/home/austritz/projects/yolo_v8_testing/photos/basketball_park2.jpg')
results[0].show()
# Out:
# /home/austritz/anaconda3/envs/my_first_env/lib/python3.12/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at /opt/conda/conda-bld/pytorch_1712609048481/work/aten/src/ATen/native/cudnn/Conv_v8.cpp:84.)
#   return F.conv2d(input, weight, bias, self.stride,
# image 1/1 /home/austritz/projects/yolo_v8_testing/photos/basketball_park2.jpg: 352x640 1 Basketball, 74.6ms
# Speed: 3.7ms preprocess, 74.6ms inference, 484.7ms postprocess per image at shape (1, 3, 352, 640)
# <PIL.Image.Image image mode=RGB size=310x163>

# %%
results = model('/home/austritz/projects/yolo_v8_testing/photos/basketball_park.jpg')
results[0].show()
# Out:
# image 1/1 /home/austritz/projects/yolo_v8_testing/photos/basketball_park.jpg: 416x640 1 Basketball, 2 Basketball Hoops, 110.5ms
# Speed: 2.0ms preprocess, 110.5ms inference, 15.9ms postprocess per image at shape (1, 3, 416, 640)
# <PIL.Image.Image image mode=RGB size=640x410>
